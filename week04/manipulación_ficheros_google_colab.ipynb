# %% [markdown]
# # En caso de manipular ficheros en Google Colab

# %%
# Solo para Google colab para subir ficheros
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f742cee1-8f42-40d7-a16e-754efcb9e1ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f742cee1-8f42-40d7-a16e-754efcb9e1ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ficheros.zip to ficheros.zip
# ...

# %%
# Para descomprimir
# !unzip /content/ficheros.zip
# Out:
# Archive:  /content/ficheros.zip
#    creating: data/
#   inflating: data/files_folder.zip
#   inflating: data/marvel-wikia-data.csv
#    creating: files_folder/
#    creating: files_folder/a_folder_in_a_zip/
#  extracting: files_folder/a_folder_in_a_zip/file_3.txt
#  extracting: files_folder/a_number.txt
#   inflating: files_folder/echo_read_script.sh
#  extracting: files_folder/echo_script.sh
#  extracting: files_folder/endless_script.sh
#   inflating: files_folder/file_1.txt
#  extracting: files_folder/file_2.txt
#  extracting: files_folder/original_file.txt
#   inflating: files_folder/somehow_big_file.txt
#   inflating: files_folder/zip_with_multiple_files.zip

# %%
# !ls -l /content/files_folder
# Out:
# total 284
# drwxr-xr-x 2 root root   4096 Jul  1 15:33 a_folder_in_a_zip
# -rw-r--r-- 1 root root      3 Jul  1 15:33 a_number.txt
# -rw-r--r-- 1 root root     78 Jul  1 15:33 echo_read_script.sh
# -rw-r--r-- 1 root root     37 Jul  1 15:33 echo_script.sh
# -rw-r--r-- 1 root root     41 Jul  1 15:33 endless_script.sh
# -rw-r--r-- 1 root root    823 Jul  1 15:33 file_1.txt
# -rw-r--r-- 1 root root     17 Jul  1 15:33 file_2.txt
# -rw-r--r-- 1 root root      0 Jul  1 15:33 original_file.txt
# -rw-r--r-- 1 root root 256041 Jul  1 15:33 somehow_big_file.txt
# -rw-r--r-- 1 root root   1051 Jul  1 15:33 zip_with_multiple_files.zip

# %%
# importamos el módulo
import os
nombre_fichero = 'test_file'
# Abrir el fichero test_file.txt para escritura
out = open(f'/content/files_folder/{nombre_fichero}.txt', 'w')

# Escribimos la palabra 'test' en este archivo
out.write('test_2')

# Cerramos el fichero
out.close()

# %%
# En caso de crear directorios
# !mkdir /content/pepito/

# %%
# Comprobamos que existe una carpeta pepito
# !cd /content/pepito/ && ls -l
# Out:
# total 0

# %%
# Eliminar una carpeta sin ficheros
# !rmdir /content/pepito

# %%
# Si deseamos eliminar un fichero
# !rm /content/files_folder/test_file.txt

# %%
# !ls l /content/files_folder/
# Out:
# ls: cannot access 'l': No such file or directory
# /content/files_folder/:
# a_folder_in_a_zip    endless_script.sh	somehow_big_file.txt
# a_number.txt	     file_1.txt		zip_with_multiple_files.zip
# echo_read_script.sh  file_2.txt
# echo_script.sh	     original_file.txt
