# %% [markdown]
# # Ejercicio 1
#
# Los siguientes ejercicios se realizarán utilizando el dataset `dataset1.csv` proporcionado juntamente con la PEC, y que contiene la información sobre diversos pedidos. Cada fila representa un pedido. Este dataset se ha limpiado con tal de que sea más fácil manipularlo, parte de un dataset original que se puede encontrat en la siguiente [URL](https://www.kaggle.com/rohitsahoo/sales-forecasting). (Para hacer los ejercios tenéis que utilizar el dataset que os proporcionamos).
#
# Los campos del dataset son:
#
# - Order ID: ID del pedido.
# - Order Date: Fecha en la que se realizó el pedido.
# - Ship Mode: El tipo de envío del pedido, puede ser 1st C, 2nd C, std o Same Day.
# - Customer ID: Un identificador diferente para cada cliente.
# - Customer Name: Nombre del cliente. Fijaros que los clientes están guardados "nombre apellido" con un espacio en  blanco entre las dos palabras.
# - City: Ciudad a la que se envía el pedido.
# - State: Estado (de estados unidos) al que se envía el pedido.
# - Product ID: Código identificador del producto. Cadena de caracteres que contiene mayúsculas, minúsculas y dos guiones.
# - Category: Categoría del producto enviado.
# - Sales: Precio total (en dólares) del pedido.

# %% [markdown]
# 1. Cargad el dataset y mostrad por pantalla los 5 últimos elementos.
# 2. De estos 5 últimos elementos del punto 1, mostrad los 2 primeros.
#
# **Pista**: Recordad que podéis utilizar librerías como `pandas` para cargar el conjunto de datos de forma sencilla.

# %%
import pandas as pd

# %%
ruta_fichero = "https://raw.githubusercontent.com/marcusRB/IDbootcamps_DataScience_student_PT_10201/master/week07/datasets/dataset1.csv"

# %%
# # En caso de realizar la operación en Google Colab
# ruta_fichero_colab = "/content/dataset1.csv"

# %%
# # En caso de realizar la operación en local
# ruta_fichero_local = "<ruta_fichero_relativa>"

# %%
# Lectura del fichero con pandas.read_csv()
df = pd.read_csv(ruta_fichero, sep=",")
df
# Out:
#          Order ID  Order Date Ship Mode  ...    Product ID    Category     Sales
# 0     2017-152156  08/11/2017     2nd C  ...  FUR-BO-11798   Furniture  261.9600
# 1     2017-152156  08/11/2017     2nd C  ...  FUR-CH-10454   Furniture  731.9400
# 2     2017-138688  12/06/2017     2nd C  ...  OFF-LA-10240   Off.Supp.   14.6200
# 3     2016-108966  11/10/2016       std  ...  FUR-TA-10577   Furniture  957.5775
# 4     2016-108966  11/10/2016       std  ...  OFF-ST-10760   Off.Supp.   22.3680
# ...           ...         ...       ...  ...           ...         ...       ...
# 9794  2017-125920  21/05/2017       std  ...  OFF-BI-13429   Off.Supp.    3.7980
# 9795  2016-128608  12/01/2016       std  ...  OFF-AR-11374   Off.Supp.   10.3680
# 9796  2016-128608  12/01/2016       std  ...  TEC-PH-14977  Technology  235.1880
# 9797  2016-128608  12/01/2016       std  ...  TEC-PH-10912  Technology   26.3760
# 9798  2016-128608  12/01/2016       std  ...  TEC-AC-10487  Technology   10.3840
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9799 entries, 0 to 9798
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9799 non-null   object
#  1   Order Date     9799 non-null   object
#  2   Ship Mode      9799 non-null   object
#  3   Customer ID    9799 non-null   object
#  4   Customer Name  9799 non-null   object
#  5   City           9799 non-null   object
#  6   State          9799 non-null   object
#  7   Product ID     9799 non-null   object
#  8   Category       9799 non-null   object
#  9   Sales          9799 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 765.7+ KB

# %%
df.shape
# Out:
# (9799, 10)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.Sales
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9794      3.7980
# 9795     10.3680
# 9796    235.1880
# 9797     26.3760
# 9798     10.3840
# Name: Sales, Length: 9799, dtype: float64

# %%
df['Order ID']
# Out:
# 0       2017-152156
# 1       2017-152156
# 2       2017-138688
# 3       2016-108966
# 4       2016-108966
#            ...
# 9794    2017-125920
# 9795    2016-128608
# 9796    2016-128608
# 9797    2016-128608
# 9798    2016-128608
# Name: Order ID, Length: 9799, dtype: object

# %%
type(df['Order ID'])
# Out:
# pandas.core.series.Series

# %%
# Mostramos los 5 primeros resultados
df.head()
# Out:
#       Order ID  Order Date Ship Mode  ...    Product ID   Category     Sales
# 0  2017-152156  08/11/2017     2nd C  ...  FUR-BO-11798  Furniture  261.9600
# 1  2017-152156  08/11/2017     2nd C  ...  FUR-CH-10454  Furniture  731.9400
# 2  2017-138688  12/06/2017     2nd C  ...  OFF-LA-10240  Off.Supp.   14.6200
# 3  2016-108966  11/10/2016       std  ...  FUR-TA-10577  Furniture  957.5775
# 4  2016-108966  11/10/2016       std  ...  OFF-ST-10760  Off.Supp.   22.3680
#
# [5 rows x 10 columns]

# %%
# Mostramos los 5 últimos resultados
df.tail()
# Out:
#          Order ID  Order Date Ship Mode  ...    Product ID    Category    Sales
# 9794  2017-125920  21/05/2017       std  ...  OFF-BI-13429   Off.Supp.    3.798
# 9795  2016-128608  12/01/2016       std  ...  OFF-AR-11374   Off.Supp.   10.368
# 9796  2016-128608  12/01/2016       std  ...  TEC-PH-14977  Technology  235.188
# 9797  2016-128608  12/01/2016       std  ...  TEC-PH-10912  Technology   26.376
# 9798  2016-128608  12/01/2016       std  ...  TEC-AC-10487  Technology   10.384
#
# [5 rows x 10 columns]

# %%
# Alternativa Mostramos los 5 últimos
df[-5:]
# Out:
#          Order ID  Order Date Ship Mode  ...    Product ID    Category    Sales
# 9794  2017-125920  21/05/2017       std  ...  OFF-BI-13429   Off.Supp.    3.798
# 9795  2016-128608  12/01/2016       std  ...  OFF-AR-11374   Off.Supp.   10.368
# 9796  2016-128608  12/01/2016       std  ...  TEC-PH-14977  Technology  235.188
# 9797  2016-128608  12/01/2016       std  ...  TEC-PH-10912  Technology   26.376
# 9798  2016-128608  12/01/2016       std  ...  TEC-AC-10487  Technology   10.384
#
# [5 rows x 10 columns]

# %%
# Mostramos los 2 primeros de estos 5 últimos
df[-5:-3:]
# Out:
#          Order ID  Order Date Ship Mode  ...    Product ID   Category   Sales
# 9794  2017-125920  21/05/2017       std  ...  OFF-BI-13429  Off.Supp.   3.798
# 9795  2016-128608  12/01/2016       std  ...  OFF-AR-11374  Off.Supp.  10.368
#
# [2 rows x 10 columns]

# %% [markdown]
# # Ejercicio 2
#
# Partiendo del dataset anterior:
#
# 1. Queremos implementar de manera simple un sistema para asociar a cada nombre de cliente su "ID". Utilizad la estructura de datos más adecuada (justificad el motivo) y mostradla. Cada pareja debe guardarse una sola vez.
#
# 2. Cread una lista con los nombres de los clientes ordenados lexicograficamente.
#
# Partiendo de la lista creada en el punto 2 y usando _**list slicing**_:
#
# 3. Cread y mostrad por pantalla una lista de los clientes en ordre lexicografico inverso.
# 4. Cread y mostrad por pantalla una lista de las posiciones múltiples de 3.
#
# Partiendo de la lista creada en el punto 2 i utilizando _**list comprehensions**_:
#
# 5.  Cread y mostrad por pantalla una lista de los clientes con nombre de longitud 5.
# **Nota**: Observad que los clientes están guardados con nombre y apellido. Por ejemplo, el cliente "Alejandro Grove" no tiene nombre de longitud 5, pero el cliente "Emily Burns" sí.
#
# 6.  Cread y mostrad por pantalla una lista de los clientes con apellido que empieza por "Z".

# %%
df.head()
# Out:
#       Order ID  Order Date Ship Mode  ...    Product ID   Category     Sales
# 0  2017-152156  08/11/2017     2nd C  ...  FUR-BO-11798  Furniture  261.9600
# 1  2017-152156  08/11/2017     2nd C  ...  FUR-CH-10454  Furniture  731.9400
# 2  2017-138688  12/06/2017     2nd C  ...  OFF-LA-10240  Off.Supp.   14.6200
# 3  2016-108966  11/10/2016       std  ...  FUR-TA-10577  Furniture  957.5775
# 4  2016-108966  11/10/2016       std  ...  OFF-ST-10760  Off.Supp.   22.3680
#
# [5 rows x 10 columns]

# %%
# Respuesta 2.1
dict_ids_names = dict(
    zip(
        list(df['Customer ID']),
        list(df['Customer Name'])
    )
)
print(dict_ids_names)
# Out:
# {'CG-12520': 'Claire Gute', 'DV-13045': 'Darrin Van Huff', 'SO-20335': "Sean O'Donnell", 'BH-11710': 'Brosina Hoffman', 'AA-10480': 'Andrew Allen', 'IM-15070': 'Irene Maddox', 'HP-14815': 'Harold Pawlan', 'PK-19075': 'Pete Kriz', 'AG-10270': 'Alejandro Grove', 'ZD-21925': 'Zuschuss Donatelli', 'KB-16585': 'Ken Black', 'SF-20065': 'Sandra Flanagan', 'EB-13870': 'Emily Burns', 'EH-13945': 'Eric Hoffmann', 'TB-21520': 'Tracy Blumstein', 'MA-17560': 'Matt Abelman', 'GH-14485': 'Gene Hale', 'SN-20710': 'Steve Nguyen', 'LC-16930': 'Linda Cazamias', 'RA-19885': 'Ruben Ausman', 'ES-14080': 'Erin Smith', 'ON-18715': 'Odella Nelson', 'PO-18865': "Patrick O'Donnell", 'LH-16900': 'Lena Hernandez', 'DP-13000': 'Darren Powers', 'JM-15265': 'Janet Molinari', 'TB-21055': 'Ted Butterfield', 'KM-16720': 'Kunst Miller', 'PS-18970': 'Paul Stevenson', 'BS-11590': 'Brendan Sweed', 'KD-16270': 'Karen Daniels', 'HM-14980': 'Henry MacAllister', 'JE-15745': 'Joel Eaton', 'KB-16600': 'Ken Brennan', 'SC-20770':
# ...

# %%
# Respuesta 2.1
dict_ids_names = dict(
    zip(
        df['Customer ID'],
        df['Customer Name']
    )
)
print(dict_ids_names)
# Out:
# {'CG-12520': 'Claire Gute', 'DV-13045': 'Darrin Van Huff', 'SO-20335': "Sean O'Donnell", 'BH-11710': 'Brosina Hoffman', 'AA-10480': 'Andrew Allen', 'IM-15070': 'Irene Maddox', 'HP-14815': 'Harold Pawlan', 'PK-19075': 'Pete Kriz', 'AG-10270': 'Alejandro Grove', 'ZD-21925': 'Zuschuss Donatelli', 'KB-16585': 'Ken Black', 'SF-20065': 'Sandra Flanagan', 'EB-13870': 'Emily Burns', 'EH-13945': 'Eric Hoffmann', 'TB-21520': 'Tracy Blumstein', 'MA-17560': 'Matt Abelman', 'GH-14485': 'Gene Hale', 'SN-20710': 'Steve Nguyen', 'LC-16930': 'Linda Cazamias', 'RA-19885': 'Ruben Ausman', 'ES-14080': 'Erin Smith', 'ON-18715': 'Odella Nelson', 'PO-18865': "Patrick O'Donnell", 'LH-16900': 'Lena Hernandez', 'DP-13000': 'Darren Powers', 'JM-15265': 'Janet Molinari', 'TB-21055': 'Ted Butterfield', 'KM-16720': 'Kunst Miller', 'PS-18970': 'Paul Stevenson', 'BS-11590': 'Brendan Sweed', 'KD-16270': 'Karen Daniels', 'HM-14980': 'Henry MacAllister', 'JE-15745': 'Joel Eaton', 'KB-16600': 'Ken Brennan', 'SC-20770':
# ...

# %%
# Mostramos los índices
df.index
# Out:
# RangeIndex(start=0, stop=9799, step=1)

# %%
# Respuesta 2.1 alternativa
customer_df = df[['Customer ID', 'Customer Name']].set_index('Customer ID')
customer_df
# Out:
#                 Customer Name
# Customer ID
# CG-12520          Claire Gute
# CG-12520          Claire Gute
# DV-13045      Darrin Van Huff
# SO-20335       Sean O'Donnell
# SO-20335       Sean O'Donnell
# ...                       ...
# SH-19975        Sally Hughsby
# CS-12490     Cindy Schnelling
# CS-12490     Cindy Schnelling
# CS-12490     Cindy Schnelling
# CS-12490     Cindy Schnelling
#
# [9799 rows x 1 columns]

# %%
type(customer_df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.DataFrame.to_dict()

# %%
customer_df.to_dict('dict')
# Out:
# {'Customer Name': {'AA-10315': 'Alex Avila',
#   'AA-10375': 'Allen Armold',
#   'AA-10480': 'Andrew Allen',
#   'AA-10645': 'Anna Andreadi',
#   'AB-10015': 'Aaron Bergman',
#   'AB-10060': 'Adam Bellavance',
#   'AB-10105': 'Adrian Barton',
#   'AB-10150': 'Aimee Bixby',
#   'AB-10165': 'Alan Barnes',
#   'AB-10255': 'Alejandro Ballentine',
#   'AB-10600': 'Ann Blume',
#   'AC-10420': 'Alyssa Crouse',
#   'AC-10450': 'Amy Cox',
#   'AC-10615': 'Ann Chong',
#   'AC-10660': 'Anna Chung',
#   'AD-10180': 'Alan Dominguez',
#   'AF-10870': 'Art Ferguson',
#   'AF-10885': 'Art Foster',
#   'AG-10270': 'Alejandro Grove',
#   'AG-10300': 'Aleksandra Gannaway',
#   'AG-10330': 'Alex Grayson',
#   'AG-10390': 'Allen Goldenen',
#   'AG-10495': 'Andrew Gjertsen',
#   'AG-10525': 'Andy Gerbode',
#   'AG-10675': 'Anna Gayman',
#   'AG-10765': 'Anthony Garverick',
#   'AG-10900': 'Arthur Gainer',
#   'AH-10030': 'Aaron Hawkins',
#   'AH-10075': 'Adam Hart',
#   'AH-10120': 'Adrian Hane',
# ...

# %%
from collections import OrderedDict

# %%
customer_df.head()
# Out:
#                Customer Name
# Customer ID
# CG-12520         Claire Gute
# CG-12520         Claire Gute
# DV-13045     Darrin Van Huff
# SO-20335      Sean O'Donnell
# SO-20335      Sean O'Donnell

# %%
nuevo_dict = customer_df.to_dict('dict', into=OrderedDict)
nuevo_dict
# Out:
# OrderedDict([('Customer Name',
#               OrderedDict([('CG-12520', 'Claire Gute'),
#                            ('DV-13045', 'Darrin Van Huff'),
#                            ('SO-20335', "Sean O'Donnell"),
#                            ('BH-11710', 'Brosina Hoffman'),
#                            ('AA-10480', 'Andrew Allen'),
#                            ('IM-15070', 'Irene Maddox'),
#                            ('HP-14815', 'Harold Pawlan'),
#                            ('PK-19075', 'Pete Kriz'),
#                            ('AG-10270', 'Alejandro Grove'),
#                            ('ZD-21925', 'Zuschuss Donatelli'),
#                            ('KB-16585', 'Ken Black'),
#                            ('SF-20065', 'Sandra Flanagan'),
#                            ('EB-13870', 'Emily Burns'),
#                            ('EH-13945', 'Eric Hoffmann'),
#                            ('TB-21520', 'Tracy Blumstein'),
#                            ('MA-17560', 'Matt Abelman'),
# ...

# %%
type(nuevo_dict)
# Out:
# collections.OrderedDict

# %%
type(customer_df.to_dict('dict'))
# Out:
# dict

# %%
# Mostramos un ejemplo de recogida del valor
nuevo_dict.get('Customer Name')['CG-12520']
# Out:
# 'Claire Gute'

# %%
nuevo_dict.values()
# Out:
# odict_values([OrderedDict([('CG-12520', 'Claire Gute'), ('DV-13045', 'Darrin Van Huff'), ('SO-20335', "Sean O'Donnell"), ('BH-11710', 'Brosina Hoffman'), ('AA-10480', 'Andrew Allen'), ('IM-15070', 'Irene Maddox'), ('HP-14815', 'Harold Pawlan'), ('PK-19075', 'Pete Kriz'), ('AG-10270', 'Alejandro Grove'), ('ZD-21925', 'Zuschuss Donatelli'), ('KB-16585', 'Ken Black'), ('SF-20065', 'Sandra Flanagan'), ('EB-13870', 'Emily Burns'), ('EH-13945', 'Eric Hoffmann'), ('TB-21520', 'Tracy Blumstein'), ('MA-17560', 'Matt Abelman'), ('GH-14485', 'Gene Hale'), ('SN-20710', 'Steve Nguyen'), ('LC-16930', 'Linda Cazamias'), ('RA-19885', 'Ruben Ausman'), ('ES-14080', 'Erin Smith'), ('ON-18715', 'Odella Nelson'), ('PO-18865', "Patrick O'Donnell"), ('LH-16900', 'Lena Hernandez'), ('DP-13000', 'Darren Powers'), ('JM-15265', 'Janet Molinari'), ('TB-21055', 'Ted Butterfield'), ('KM-16720', 'Kunst Miller'), ('PS-18970', 'Paul Stevenson'), ('BS-11590', 'Brendan Sweed'), ('KD-16270', 'Karen Daniels'), ('HM-1498
# ...

# %%
# Crear una lista de nombres ordenados
lista_clientes = sorted(list(dict_ids_names.values()))
lista_clientes
# Out:
# ['Aaron Bergman',
#  'Aaron Hawkins',
#  'Aaron Smayling',
#  'Adam Bellavance',
#  'Adam Hart',
#  'Adam Shillingsburg',
#  'Adrian Barton',
#  'Adrian Hane',
#  'Adrian Shami',
#  'Aimee Bixby',
#  'Alan Barnes',
#  'Alan Dominguez',
#  'Alan Haines',
#  'Alan Hwang',
#  'Alan Schoenberger',
#  'Alan Shonely',
#  'Alejandro Ballentine',
#  'Alejandro Grove',
#  'Alejandro Savely',
#  'Aleksandra Gannaway',
#  'Alex Avila',
#  'Alex Grayson',
#  'Alex Russell',
#  'Alice McCarthy',
#  'Allen Armold',
#  'Allen Goldenen',
#  'Allen Rosenblatt',
#  'Alyssa Crouse',
#  'Alyssa Tate',
#  'Amy Cox',
#  'Amy Hunt',
#  'Andrew Allen',
#  'Andrew Gjertsen',
#  'Andrew Roberts',
#  'Andy Gerbode',
#  'Andy Reiter',
#  'Andy Yotov',
#  'Anemone Ratner',
#  'Angele Hood',
#  'Ann Blume',
#  'Ann Chong',
#  'Ann Steele',
#  'Anna Andreadi',
#  'Anna Chung',
#  'Anna Gayman',
#  'Anna Häberlin',
#  'Anne McFarland',
#  'Anne Pryor',
#  'Annie Thurman',
#  'Annie Zypern',
#  'Anthony Garverick',
# ...

# %%
# Alternativa con DataFrame
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Mode', 'Customer ID', 'Customer Name',
#        'City', 'State', 'Product ID', 'Category', 'Sales'],
#       dtype='object')

# %%
customer_name_list = []
for name in list(set(df['Customer Name'])):
  customer_name_list.append(name)

# %%
# Ordenamos en formato asc.
customer_name_list.sort()

# %%
customer_name_list
# Out:
# ['Aaron Bergman',
#  'Aaron Hawkins',
#  'Aaron Smayling',
#  'Adam Bellavance',
#  'Adam Hart',
#  'Adam Shillingsburg',
#  'Adrian Barton',
#  'Adrian Hane',
#  'Adrian Shami',
#  'Aimee Bixby',
#  'Alan Barnes',
#  'Alan Dominguez',
#  'Alan Haines',
#  'Alan Hwang',
#  'Alan Schoenberger',
#  'Alan Shonely',
#  'Alejandro Ballentine',
#  'Alejandro Grove',
#  'Alejandro Savely',
#  'Aleksandra Gannaway',
#  'Alex Avila',
#  'Alex Grayson',
#  'Alex Russell',
#  'Alice McCarthy',
#  'Allen Armold',
#  'Allen Goldenen',
#  'Allen Rosenblatt',
#  'Alyssa Crouse',
#  'Alyssa Tate',
#  'Amy Cox',
#  'Amy Hunt',
#  'Andrew Allen',
#  'Andrew Gjertsen',
#  'Andrew Roberts',
#  'Andy Gerbode',
#  'Andy Reiter',
#  'Andy Yotov',
#  'Anemone Ratner',
#  'Angele Hood',
#  'Ann Blume',
#  'Ann Chong',
#  'Ann Steele',
#  'Anna Andreadi',
#  'Anna Chung',
#  'Anna Gayman',
#  'Anna Häberlin',
#  'Anne McFarland',
#  'Anne Pryor',
#  'Annie Thurman',
#  'Annie Zypern',
#  'Anthony Garverick',
# ...

# %%
# Ejercicio 2.3
clientes_inverse = lista_clientes[::-1]
print(clientes_inverse)
# Out:
# ['Zuschuss Donatelli', 'Zuschuss Carroll', 'Yoseph Carroll', 'Yana Sorensen', 'Xylona Preis', 'William Brown', 'Vivian Mathis', 'Vivek Sundaresam', 'Vivek Grady', 'Vivek Gonzalez', 'Victoria Wilson', 'Victoria Pisteka', 'Victoria Brennan', 'Victor Preis', 'Vicky Freymann', 'Valerie Takahito', 'Valerie Mitchum', 'Valerie Dominguez', 'Trudy Schmidt', 'Trudy Glocke', 'Trudy Brown', 'Troy Staebel', 'Troy Blackwell', 'Tracy Zic', 'Tracy Poddar', 'Tracy Hopkins', 'Tracy Collins', 'Tracy Blumstein', 'Tony Sayre', 'Tony Molinari', 'Tony Chapman', 'Tonja Turnell', 'Tom Stivers', 'Tom Prescott', 'Tom Boeckenhauer', 'Tom Ashbrook', 'Todd Sumrall', 'Todd Boyes', 'Toby Swindell', 'Toby Ritter', 'Toby Gnade', 'Toby Carlisle', 'Toby Braunhardt', 'Tim Taslimi', 'Tim Brockman', 'Tiffany House', 'Thomas Thornton', 'Thomas Seio', 'Thomas Brumley', 'Thomas Boland', 'Theresa Swint', 'Theresa Coyne', 'Theone Pippenger', 'Thea Hudgings', 'Thea Hendricks', 'Thais Sissman', 'Ted Trevino', 'Ted Butterfield', 
# ...

# %%
lista_clientes.sort(reverse=True)

# %%
lista_clientes
# Out:
# ['Zuschuss Donatelli',
#  'Zuschuss Carroll',
#  'Yoseph Carroll',
#  'Yana Sorensen',
#  'Xylona Preis',
#  'William Brown',
#  'Vivian Mathis',
#  'Vivek Sundaresam',
#  'Vivek Grady',
#  'Vivek Gonzalez',
#  'Victoria Wilson',
#  'Victoria Pisteka',
#  'Victoria Brennan',
#  'Victor Preis',
#  'Vicky Freymann',
#  'Valerie Takahito',
#  'Valerie Mitchum',
#  'Valerie Dominguez',
#  'Trudy Schmidt',
#  'Trudy Glocke',
#  'Trudy Brown',
#  'Troy Staebel',
#  'Troy Blackwell',
#  'Tracy Zic',
#  'Tracy Poddar',
#  'Tracy Hopkins',
#  'Tracy Collins',
#  'Tracy Blumstein',
#  'Tony Sayre',
#  'Tony Molinari',
#  'Tony Chapman',
#  'Tonja Turnell',
#  'Tom Stivers',
#  'Tom Prescott',
#  'Tom Boeckenhauer',
#  'Tom Ashbrook',
#  'Todd Sumrall',
#  'Todd Boyes',
#  'Toby Swindell',
#  'Toby Ritter',
#  'Toby Gnade',
#  'Toby Carlisle',
#  'Toby Braunhardt',
#  'Tim Taslimi',
#  'Tim Brockman',
#  'Tiffany House',
#  'Thomas Thornton',
#  'Thomas Seio',
#  'Thomas Brumley',
# ...

# %%
# Ej. 4
lista_clientes[::3]
# Out:
# ['Zuschuss Donatelli',
#  'Yana Sorensen',
#  'Vivian Mathis',
#  'Vivek Gonzalez',
#  'Victoria Brennan',
#  'Valerie Takahito',
#  'Trudy Schmidt',
#  'Troy Staebel',
#  'Tracy Poddar',
#  'Tracy Blumstein',
#  'Tony Chapman',
#  'Tom Prescott',
#  'Todd Sumrall',
#  'Toby Ritter',
#  'Toby Braunhardt',
#  'Tiffany House',
#  'Thomas Brumley',
#  'Theresa Coyne',
#  'Thea Hendricks',
#  'Ted Butterfield',
#  'Tamara Manning',
#  'Sylvia Foulston',
#  'Susan Pistek',
#  'Sung Shariari',
#  'Sue Ann Reed',
#  'Stewart Visinsky',
#  'Steven Roelle',
#  'Steve Chapman',
#  'Stephanie Phelps',
#  'Speros Goranitis',
#  'Skye Norling',
#  'Shirley Schmidt',
#  'Sheri Gordon',
#  'Sharelle Roach',
#  'Shahid Collister',
#  "Sean O'Donnell",
#  'Sean Braxton',
#  'Scot Wooten',
#  'Sarah Foster',
#  'Sara Luxemburg',
#  'Sanjit Engle',
#  'Sandra Flanagan',
#  'Sam Craven',
#  'Sally Hughsby',
#  "Russell D'Ascenzo",
#  'Ruben Ausman',
#  'Roy Französisch',
#  'Ross Baird',
# ...

# %%
# Alternativa
for i, name in enumerate(customer_name_list):
  print(i, name)
# Out:
# 0 Aaron Bergman
# 1 Aaron Hawkins
# 2 Aaron Smayling
# 3 Adam Bellavance
# 4 Adam Hart
# 5 Adam Shillingsburg
# 6 Adrian Barton
# 7 Adrian Hane
# 8 Adrian Shami
# 9 Aimee Bixby
# 10 Alan Barnes
# 11 Alan Dominguez
# 12 Alan Haines
# 13 Alan Hwang
# 14 Alan Schoenberger
# 15 Alan Shonely
# 16 Alejandro Ballentine
# 17 Alejandro Grove
# 18 Alejandro Savely
# 19 Aleksandra Gannaway
# 20 Alex Avila
# 21 Alex Grayson
# 22 Alex Russell
# 23 Alice McCarthy
# 24 Allen Armold
# 25 Allen Goldenen
# 26 Allen Rosenblatt
# 27 Alyssa Crouse
# 28 Alyssa Tate
# 29 Amy Cox
# 30 Amy Hunt
# 31 Andrew Allen
# 32 Andrew Gjertsen
# 33 Andrew Roberts
# 34 Andy Gerbode
# 35 Andy Reiter
# 36 Andy Yotov
# 37 Anemone Ratner
# 38 Angele Hood
# 39 Ann Blume
# 40 Ann Chong
# 41 Ann Steele
# 42 Anna Andreadi
# 43 Anna Chung
# 44 Anna Gayman
# 45 Anna Häberlin
# 46 Anne McFarland
# 47 Anne Pryor
# 48 Annie Thurman
# 49 Annie Zypern
# 50 Anthony Garverick
# 51 Anthony Jacobs
# 52 Anthony Johnson
# ...

# %%
customer_name_by_3 = list()
idx = 3
for i in range(1, len(customer_name_list)):
  if i % 3 == 0:
    for name in customer_name_list[:i:idx]:
      customer_name_by_3.append(name)

# %%
customer_name_by_3
# Out:
# ['Aaron Bergman',
#  'Aaron Bergman',
#  'Adam Bellavance',
#  'Aaron Bergman',
#  'Adam Bellavance',
#  'Adrian Barton',
#  'Aaron Bergman',
#  'Adam Bellavance',
#  'Adrian Barton',
#  'Aimee Bixby',
#  'Aaron Bergman',
#  'Adam Bellavance',
#  'Adrian Barton',
#  'Aimee Bixby',
#  'Alan Haines',
#  'Aaron Bergman',
#  'Adam Bellavance',
#  'Adrian Barton',
#  'Aimee Bixby',
#  'Alan Haines',
#  'Alan Shonely',
#  'Aaron Bergman',
#  'Adam Bellavance',
#  'Adrian Barton',
#  'Aimee Bixby',
#  'Alan Haines',
#  'Alan Shonely',
#  'Alejandro Savely',
#  'Aaron Bergman',
#  'Adam Bellavance',
#  'Adrian Barton',
#  'Aimee Bixby',
#  'Alan Haines',
#  'Alan Shonely',
#  'Alejandro Savely',
#  'Alex Grayson',
#  'Aaron Bergman',
#  'Adam Bellavance',
#  'Adrian Barton',
#  'Aimee Bixby',
#  'Alan Haines',
#  'Alan Shonely',
#  'Alejandro Savely',
#  'Alex Grayson',
#  'Allen Armold',
#  'Aaron Bergman',
#  'Adam Bellavance',
#  'Adrian Barton',
#  'Aimee Bixby',
#  'Alan Haines',
# ...

# %%
# Ej 5
lista_nombres = [(name.split(sep=" ")[0]) for name in customer_name_list]
[nombre for nombre in lista_nombres if len(nombre) == 5]
# Out:
# ['Aaron',
#  'Aaron',
#  'Aaron',
#  'Aimee',
#  'Alice',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Annie',
#  'Annie',
#  'Barry',
#  'Barry',
#  'Barry',
#  'Barry',
#  'Barry',
#  'Barry',
#  'Becky',
#  'Becky',
#  'Becky',
#  'Bobby',
#  'Bobby',
#  'Bobby',
#  'Brian',
#  'Brian',
#  'Brian',
#  'Brian',
#  'Brian',
#  'Brian',
#  'Bruce',
#  'Bruce',
#  'Bruce',
#  'Bryan',
#  'Bryan',
#  'Bryan',
#  'Carol',
#  'Carol',
#  'Carol',
#  'Cathy',
#  'Cathy',
#  'Cathy',
#  'Chris',
#  'Chris',
#  'Chris',
#  'Chuck',
#  'Chuck',
#  'Chuck',
#  'Cindy',
#  'Cindy',
#  'Cindy',
#  'Corey',
#  'Corey',
#  'Craig',
#  'Craig',
#  'Craig',
#  'Craig',
#  'Craig',
#  'Craig',
#  'Dario',
#  'David',
#  'David',
#  'David',
#  'David',
#  'David',
#  'David',
#  'Debra',
#  'Denny',
#  'Denny',
#  'Denny',
#  'Duane',
#  'Duane',
#  'Duane',
#  'Eleni',
#  'Ellis',
#  'Emily',
#  'Emily',
#  'Emily',
#  'Emily',
#  'Erica',
#  'Erica',
#  'Erica',
#  'Erica',
#  'Filia',
#  'Frank',
# ...

# %%
# Alternativa
# %%timeit
for name in customer_name_list:
  if name[5] == " ":
    print(name)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Sonia Cooley
# Sonia Sunley
# Steve Carroll
# Steve Chapman
# Steve Nguyen
# Susan Gilcrest
# Susan MacKendrick
# Susan Pistek
# Susan Vittorini
# Tanja Norvell
# Thais Sissman
# Tonja Turnell
# Tracy Blumstein
# Tracy Collins
# Tracy Hopkins
# Tracy Poddar
# Tracy Zic
# Trudy Brown
# Trudy Glocke
# Trudy Schmidt
# Vicky Freymann
# Vivek Gonzalez
# Vivek Grady
# Vivek Sundaresam
# Aaron Bergman
# Aaron Hawkins
# Aaron Smayling
# Aimee Bixby
# Alice McCarthy
# Allen Armold
# Allen Goldenen
# Allen Rosenblatt
# Annie Thurman
# Annie Zypern
# Barry Blumstein
# Barry Franz
# Barry Französisch
# Barry Gonzalez
# Barry Pond
# Barry Weirich
# Becky Castell
# Becky Martin
# Becky Pak
# Bobby Elias
# Bobby Odegard
# Bobby Trafton
# Brian Dahlen
# Brian DeCherney
# Brian Derr
# Brian Moss
# Brian Stugart
# Brian Thompson
# Bruce Degenhardt
# Bruce Geld
# Bruce Stewart
# Bryan Davis
# Bryan Mills
# Bryan Spruell
# Carol Adams
# ...

# %% [markdown]
# ```
# lista_nombres = [(name.split(sep=" ")[0]) for name in customer_name_list]
# [nombre for nombre in lista_nombres if len(nombre) == 5]
# ```

# %%
# %%timeit
clientes_5 = [c for c in lista_clientes if len(c.split(" ")[0]) == 5]
# Out:
# 1000 loops, best of 5: 256 µs per loop

# %%
clientes_5
# Out:
# ['Vivek Sundaresam',
#  'Vivek Grady',
#  'Vivek Gonzalez',
#  'Vicky Freymann',
#  'Trudy Schmidt',
#  'Trudy Glocke',
#  'Trudy Brown',
#  'Tracy Zic',
#  'Tracy Poddar',
#  'Tracy Hopkins',
#  'Tracy Collins',
#  'Tracy Blumstein',
#  'Tonja Turnell',
#  'Thais Sissman',
#  'Tanja Norvell',
#  'Susan Vittorini',
#  'Susan Pistek',
#  'Susan MacKendrick',
#  'Susan Gilcrest',
#  'Steve Nguyen',
#  'Steve Chapman',
#  'Steve Carroll',
#  'Sonia Sunley',
#  'Sonia Cooley',
#  'Sheri Gordon',
#  'Shaun Weien',
#  'Shaun Chance',
#  'Scott Williamson',
#  'Scott Cohen',
#  'Sarah Jordon',
#  'Sarah Foster',
#  'Sarah Brown',
#  'Sarah Bern',
#  'Sally Matthias',
#  'Sally Knutson',
#  'Sally Hughsby',
#  'Ruben Dartt',
#  'Ruben Ausman',
#  'Roger Demir',
#  'Roger Barcio',
#  'Ritsa Hightower',
#  'Randy Ferguson',
#  'Randy Bradley',
#  'Ralph Ritter',
#  'Ralph Kennedy',
#  'Ralph Arnett',
#  'Peter McVee',
#  'Peter Fuller',
#  'Peter Bühler',
#  'Neoma Murray',
# ...

# %%
# Ej. 2.6
# %%timeit
clientes_apellidoZ = [c for c in lista_clientes if c.split(" ")[-1][0] == "Z"]
print(clientes_apellidoZ)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# ['Tracy Zic', 'Sam Zeldin', 'Nick Zandusky', 'Mary Zewe', 'Maria Zettner', 'Henia Zydlo', 'George Zrebassa', 'Gary Zandusky', 'Annie Zypern']
# ['Tracy Zic', 'Sam Zeldin', 'Nick Zandusky', 'Mary Zewe', 'Maria Zettner', 'Henia Zydlo', 'George Zrebassa', 'Gary Zandusky', 'Annie Zypern']
# ['Tracy Zic', 'Sam Zeldin', 'Nick Zandusky', 'Mary Zewe', 'Maria Zettner', 'Henia Zydlo', 'George Zrebassa', 'Gary Zandusky', 'Annie Zypern']
# ['Tracy Zic', 'Sam Zeldin', 'Nick Zandusky', 'Mary Zewe', 'Maria Zettner', 'Henia Zydlo', 'George Zrebassa', 'Gary Zandusky', 'Annie Zypern']
# ['Tracy Zic', 'Sam Zeldin', 'Nick Zandusky', 'Mary Zewe', 'Maria Zettner', 'Henia Zydlo', 'George Zrebassa', 'Gary Zandusky', 'Annie Zypern']
# ['Tracy Zic', 'Sam Zeldin', 'Nick Zandusky', 'Mary Zewe', 'Maria Zettner', 'Henia Zydlo', 'George Zrebassa', 'Gary Zandusky', 'Annie Zypern']
# ...

# %%
# %%timeit
lista_Z = [apellido.split(" ",1)[-1] for apellido in customer_name_list]
[apellido for apellido in lista_Z if apellido.startswith("Z")]
# Out:
# The slowest run took 6.26 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000 loops, best of 5: 300 µs per loop

# %%
import re
# %timeit [c for c in lista_clientes if re.match(r"^\w+\s[Z]", c)]
# Out:
# 1000 loops, best of 5: 853 µs per loop

# %% [markdown]
# # Ejercicio 4
#
# 1. Mostrad por pantalla el nombre de todos los estados a los que se ha enviado pedidos de tipo "Furniture" (sin repeticiones).
#
# 2. Mostrad también el número de estados a los que se han enviado estos pedidos

# %%
furniture_orders = df[df['Category'] == 'Furniture']
furniture_orders
# Out:
#          Order ID  Order Date Ship Mode  ...    Product ID   Category      Sales
# 0     2017-152156  08/11/2017     2nd C  ...  FUR-BO-11798  Furniture   261.9600
# 1     2017-152156  08/11/2017     2nd C  ...  FUR-CH-10454  Furniture   731.9400
# 3     2016-108966  11/10/2016       std  ...  FUR-TA-10577  Furniture   957.5775
# 5     2015-115812  09/06/2015       std  ...  FUR-FU-11487  Furniture    48.8600
# 10    2015-115812  09/06/2015       std  ...  FUR-TA-11539  Furniture  1706.1840
# ...           ...         ...       ...  ...           ...        ...        ...
# 9785  2015-114377  05/11/2015  Same Day  ...  FUR-CH-14754  Furniture   149.9000
# 9786  2018-144491  27/03/2018       std  ...  FUR-BO-11811  Furniture  1023.3320
# 9787  2018-144491  27/03/2018       std  ...  FUR-CH-14063  Furniture   600.5580
# 9789  2018-144491  27/03/2018       std  ...  FUR-CH-11714  Furniture   211.2460
# 9791  2015-127166  21/05/2015     2nd C  ...  FUR-CH-13396  Furniture   107.7720
#
# ...

# %%
print(set(furniture_orders['State']))
# Out:
# {'Colorado', 'New York', 'Illinois', 'Virginia', 'New Mexico', 'Kansas', 'Minnesota', 'New Jersey', 'Georgia', 'North Carolina', 'Oregon', 'Connecticut', 'Utah', 'Alabama', 'Montana', 'Rhode Island', 'South Dakota', 'Iowa', 'Nebraska', 'Texas', 'Washington', 'Missouri', 'Wyoming', 'Maine', 'Tennessee', 'Louisiana', 'California', 'Maryland', 'Ohio', 'District of Columbia', 'Nevada', 'Idaho', 'Florida', 'Delaware', 'West Virginia', 'Indiana', 'Vermont', 'Oklahoma', 'Kentucky', 'Mississippi', 'Arkansas', 'Arizona', 'Wisconsin', 'Michigan', 'New Hampshire', 'Massachusetts', 'South Carolina', 'Pennsylvania'}

# %%
# Ej 4.2
len(set(furniture_orders['State']))
# Out:
# 48

# %% [markdown]
# # Ejercicio 5
#
# Usando el `dataset1.csv`:
#
# 1. Cread una lista con todos los años (sin repeticiones) donde el cliente con "Customer Name" "Irene Maddox" realizo un pedido con "Ship Mode" "2nd C". Mostrad los resultados por pantalla.
#
# 2. Calculad la media de pedidos de segunda clase por año realizados por la señora Maddox (ignorad los años en que no se realizó ningún pedido). Mostrad los resultados por pantalla.

# %%
from datetime import datetime as dt

# %%
df.head()
# Out:
#       Order ID  Order Date Ship Mode  ...    Product ID   Category     Sales
# 0  2017-152156  08/11/2017     2nd C  ...  FUR-BO-11798  Furniture  261.9600
# 1  2017-152156  08/11/2017     2nd C  ...  FUR-CH-10454  Furniture  731.9400
# 2  2017-138688  12/06/2017     2nd C  ...  OFF-LA-10240  Off.Supp.   14.6200
# 3  2016-108966  11/10/2016       std  ...  FUR-TA-10577  Furniture  957.5775
# 4  2016-108966  11/10/2016       std  ...  OFF-ST-10760  Off.Supp.   22.3680
#
# [5 rows x 10 columns]

# %%
df5 = df[(df['Customer Name'] == 'Irene Maddox')
 & (df['Ship Mode'] == '2nd C')]
df5
# Out:
#          Order ID  Order Date Ship Mode  ...    Product ID   Category    Sales
# 1430  2015-120768  19/12/2015     2nd C  ...  OFF-BI-11191  Off.Supp.   152.76
# 1431  2015-120768  19/12/2015     2nd C  ...  OFF-SU-14115  Off.Supp.     7.27
# 1432  2015-120768  19/12/2015     2nd C  ...  FUR-CH-10513  Furniture  1819.86
# 4982  2017-109925  06/11/2017     2nd C  ...  OFF-ST-13442  Off.Supp.    84.84
#
# [4 rows x 10 columns]

# %%
lista_anyos = []
for anyo in list(set(df['Order Date'])):
  date_obj = dt.strptime(anyo, "%d/%m/%Y")
  lista_anyos.append(dt.strftime(date_obj, "%Y"))
lista_anyos.sort()

# %%
lista_anyos
# Out:
# ['2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
# ...

# %%
list(set(lista_anyos))
# Out:
# ['2017', '2018', '2016', '2015']

# %%
dates = pd.to_datetime(df5['Order Date'])
dates
# Out:
# 1430   2015-12-19
# 1431   2015-12-19
# 1432   2015-12-19
# 4982   2017-06-11
# Name: Order Date, dtype: datetime64[ns]

# %%
years = dates.apply(lambda x: x.year)
years
# Out:
# 1430    2015
# 1431    2015
# 1432    2015
# 4982    2017
# Name: Order Date, dtype: int64

# %%
# 5.2
avgShip = years.value_counts().mean()
avgShip
# Out:
# 2.0

# %% [markdown]
# # Ejercicio 6
#
# Usando el `dataset1.csv`:
#
# Calculad los días pasados desde el primer pedido enviado a "Maryland" y el último pedido enviado a "Florida".
# Mostrad el resultado por pantalla debidamente formateado (utilizad el método **'format()'**), incluid
# un mensaje explicativo de los valores mostrados.

# %%
delta = florida_last - maryland_first
delta.days # dif. 1352

# %%
# Para realizar un subset desde un dataframe en Pandas
df.head()
# Out:
#       Order ID  Order Date Ship Mode  ...    Product ID   Category     Sales
# 0  2017-152156  08/11/2017     2nd C  ...  FUR-BO-11798  Furniture  261.9600
# 1  2017-152156  08/11/2017     2nd C  ...  FUR-CH-10454  Furniture  731.9400
# 2  2017-138688  12/06/2017     2nd C  ...  OFF-LA-10240  Off.Supp.   14.6200
# 3  2016-108966  11/10/2016       std  ...  FUR-TA-10577  Furniture  957.5775
# 4  2016-108966  11/10/2016       std  ...  OFF-ST-10760  Off.Supp.   22.3680
#
# [5 rows x 10 columns]

# %%
df6_1 = df.iloc[df['State'].isin(['Maryland','Florida'])]
df6_1
# Out:
#          Order ID  Order Date Ship Mode  ...    Product ID   Category     Sales
# 3     2016-108966  11/10/2016       std  ...  FUR-TA-10577  Furniture  957.5775
# 4     2016-108966  11/10/2016       std  ...  OFF-ST-10760  Off.Supp.   22.3680
# 43    2018-139619  19/09/2018       std  ...  OFF-ST-13282  Off.Supp.   95.6160
# 230   2018-100930  07/04/2018       std  ...  FUR-TA-11705  Furniture  233.8600
# 231   2018-100930  07/04/2018       std  ...  FUR-TA-13473  Furniture  620.6145
# ...           ...         ...       ...  ...           ...        ...       ...
# 9566  2015-130428  31/03/2015  Same Day  ...  OFF-AR-14027  Off.Supp.    4.0320
# 9584  2017-160598  26/08/2017     1st C  ...  OFF-PA-12319  Off.Supp.   31.0080
# 9768  2017-123533  24/11/2017       std  ...  FUR-BO-11619  Furniture  339.9200
# 9769  2017-123533  24/11/2017       std  ...  OFF-PA-11609  Off.Supp.   10.5280
# 9770  2017-123533  24/11/2017       std  ...  OFF-AP-12765  Off.Supp.   42.3840
#
# ...

# %%
df6_1[df6_1['State'] == 'Maryland'].sort_values(by="Order Date", ascending=True)
# Out:
#          Order ID  Order Date Ship Mode  ...    Product ID    Category    Sales
# 1176  2017-113621  01/12/2017       std  ...  FUR-CH-11270   Furniture   172.50
# 1177  2017-113621  01/12/2017       std  ...  TEC-PH-13931  Technology   179.97
# 4918  2017-160304  02/01/2017       std  ...  TEC-PH-10455  Technology   231.98
# 4917  2017-160304  02/01/2017       std  ...  FUR-BO-14709   Furniture   173.94
# 8188  2016-140375  02/10/2016     2nd C  ...  OFF-BI-10320   Off.Supp.     7.38
# ...           ...         ...       ...  ...           ...         ...      ...
# 4246  2018-117702  28/11/2018       std  ...  FUR-FU-14270   Furniture    20.90
# 4245  2018-117702  28/11/2018       std  ...  FUR-FU-10576   Furniture  1049.20
# 4244  2018-117702  28/11/2018       std  ...  OFF-AR-14582   Off.Supp.     1.64
# 7737  2018-141103  30/07/2018       std  ...  TEC-PH-13589  Technology    89.95
# 6692  2018-144225  30/09/2018     2nd C  ...  OFF-PA-10062   Off.Supp.   164.88
#
# ...

# %%
maryland = df6_1[df6_1['State'] == 'Maryland']

# %%
maryland_dates = pd.to_datetime(maryland['Order Date'],
                                format="%d/%m/%Y")

# %%
first_maryland = maryland_dates.sort_values(ascending=True).iloc[0]
first_maryland
# Out:
# Timestamp('2015-04-13 00:00:00')

# %%
florida = df6_1[df6_1['State'] == 'Florida']

# %%
florida_dates = pd.to_datetime(florida['Order Date'],
                                format="%d/%m/%Y")
last_florida = florida_dates.sort_values(ascending=True).iloc[-1]
last_florida
# Out:
# Timestamp('2018-12-25 00:00:00')

# %%
delta = last_florida - first_maryland
delta.days # dif. 1352
# Out:
# 1352

# %% [markdown]
# # Ejercicio 7
#
# Utilizando **expresiones regulares** y partiendo del `dataset1.csv`:
#
# 1. Encontrad todos los ID de producto que contengan la cadena de caracteres "TEC-PH-12".
# 2. Encontrad todos los clientes con nombre y apellido con la misma letra inicial.

# %%
# con pandas
df[df['Product ID'].str.startswith(rexp)]
# Out:
#          Order ID  Order Date Ship Mode  ...    Product ID    Category     Sales
# 7     2015-115812  09/06/2015       std  ...  TEC-PH-12275  Technology   907.152
# 11    2015-115812  09/06/2015       std  ...  TEC-PH-12033  Technology   911.424
# 54    2017-105816  11/12/2017       std  ...  TEC-PH-12447  Technology  1029.950
# 68    2015-106376  05/12/2015       std  ...  TEC-PH-12726  Technology   167.968
# 107   2018-119004  23/11/2018       std  ...  TEC-PH-12844  Technology    27.992
# ...           ...         ...       ...  ...           ...         ...       ...
# 9520  2015-169446  19/12/2015       std  ...  TEC-PH-12817  Technology   323.976
# 9567  2018-104388  05/07/2018     1st C  ...  TEC-PH-12293  Technology    79.960
# 9647  2015-150518  19/11/2015       std  ...  TEC-PH-12103  Technology   281.970
# 9672  2017-114867  23/12/2017       std  ...  TEC-PH-12645  Technology  1499.970
# 9716  2017-108210  30/05/2017  Same Day  ...  TEC-PH-12293  Technology    79.960
#
# ...

# %%
# con la librería re
product_IDs = list(set(df['Product ID']))
rexp = r"TEC-PH-12"
ids = [x for x in product_IDs if re.search(rexp, x) is not None]

# %%
ids
# Out:
# ['TEC-PH-12350',
#  'TEC-PH-12070',
#  'TEC-PH-12033',
#  'TEC-PH-12075',
#  'TEC-PH-12563',
#  'TEC-PH-12660',
#  'TEC-PH-12483',
#  'TEC-PH-12085',
#  'TEC-PH-12922',
#  'TEC-PH-12680',
#  'TEC-PH-12365',
#  'TEC-PH-12496',
#  'TEC-PH-12468',
#  'TEC-PH-12726',
#  'TEC-PH-12352',
#  'TEC-PH-12789',
#  'TEC-PH-12262',
#  'TEC-PH-12115',
#  'TEC-PH-12645',
#  'TEC-PH-12200',
#  'TEC-PH-12538',
#  'TEC-PH-12923',
#  'TEC-PH-12583',
#  'TEC-PH-12584',
#  'TEC-PH-12597',
#  'TEC-PH-12114',
#  'TEC-PH-12103',
#  'TEC-PH-12824',
#  'TEC-PH-12817',
#  'TEC-PH-12293',
#  'TEC-PH-12890',
#  'TEC-PH-12844',
#  'TEC-PH-12624',
#  'TEC-PH-12185',
#  'TEC-PH-12310',
#  'TEC-PH-12834',
#  'TEC-PH-12555',
#  'TEC-PH-12398',
#  'TEC-PH-12415',
#  'TEC-PH-12275',
#  'TEC-PH-12885',
#  'TEC-PH-12564',
#  'TEC-PH-12807',
#  'TEC-PH-12447',
#  'TEC-PH-12549',
#  'TEC-PH-12170']
